# %%
from bs4 import BeautifulSoup
from requests import get,Session
import wget
from datetime import date, timedelta, datetime
import pandas as pd
import re
import numpy as np

# %%
# path to download data to
local_path = 'data/SOS/raw/'

# %%
# Note: there's an easier way to do this starting here:
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/
# oh well.
#First, connect to the page listing all the elections
sess = Session()
url = 'http://www.sos.ca.gov/elections/prior-elections/prior-statewide-elections/'
response = sess.get(url=url)
# grab the html data
html_soup_index = BeautifulSoup(response.text, 'html.parser')

# tags containing links to elections in a given year
election_years = html_soup_index.find_all('ul',class_='dlbSpc')

# substrings for building specific election urls
url_base = 'http://www.sos.ca.gov'
url_suffix = 'statement-vote/'

# loop through election years
# (note that xls files only go back to 2002)
should_break = False
for y_idx, year in enumerate(election_years):
    # exit if we come up empty
    if should_break:
        break
        
    # loop through elections within a year
    for e_idx, election in enumerate(year.find_all('li')):
        # extract link to election results (watching out for edge cases)
        url_path = election.a['href']
        url_path = url_path.replace('/special-elections/','/statewide-election-results/')
        if url_suffix not in url_path:
            url_path += url_suffix
            
        # navigate to election results
        print('\n'+url_base+url_path)
        response = sess.get(url=url_base+url_path)
        html_soup = BeautifulSoup(response.text, 'html.parser')
        
        # find the header that precedes links to ballot measure results
        measures_header = html_soup.find_all('h2',string=re.compile('[Mm]easure'))
        if len(measures_header) == 0: # try again with 'h3'
            measures_header = html_soup.find_all('h3',string=re.compile('[Mm]easure'))
        if len(measures_header) == 0: # continue to next election if no match
            print("Couldn't find Ballot Measures section")
            continue
        
        # first <li> tag should have links to county-level results; try to grab the xls file link
        remote_filename = measures_header[0].find_next('li').find('a',href=re.compile('\.xls'))
        if remote_filename is None: # break out of all loops if no xls file (won't be any more)
            print("Couldn't find Ballot Measures xls file; exiting")
            should_break = True
            break
        remote_filename = remote_filename['href']
        print(remote_filename)
        
        # reformat election info into a local filename like "%Y%m%d_measures_[election-type].xls[x]",
        # where "[election_type]" comes from remote path (e.g. "presidential-primary-election"),
        # though these are unfortunately not standardized.
        election_info = re.split('\/',url_path)[-3]
        election_info = re.split('-',election_info)
        date_str = datetime.strptime('-'.join(election_info[-3:]),'%B-%d-%Y').strftime('%Y%m%d')
        file_suffix = re.split('\.',remote_filename)[-1]
        filename = date_str+'_measures_'+'-'.join(election_info[:-3])+'.'+file_suffix
        print(filename)
        wget.download(remote_filename,local_path+filename)
# Out:
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-8-2016/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2016-general/ssov/ballot-measures-summary-by-county.xls
# 20161108_measures_general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/presidential-primary-election-june-7-2016/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2016-primary/ssov/09-ballot-measures-summary.xls
# 20160607_measures_presidential-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-4-2014/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2014-general/ssov/ballot-measures-summary.xls
# 20141104_measures_general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/statewide-direct-primary-election-june-3-2014/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2014-primary/ssov/ballot-measures-summary.xls
# 20140603_measures_statewide-direct-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-6-2012/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2012-general/ssov/ballot-measures-summary-by-county.xls
# 20121106_measures_general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/presidential-primary-election-june-5-2012/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2012-primary/ssov/ballot-measures-summary.xls
# 20120605_measures_presidential-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-2-2010/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2010-general/ssov/ballot-measures-summary.xls
# 20101102_measures_general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/statewide-direct-primary-election-june-8-2010/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2010-primary/ssov/ballot-measures-summary.xls
# 20100608_measures_statewide-direct-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/statewide-special-election-may-19-2009/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2009-special/ssov/1-6-summary-by-county.xls
# 20090519_measures_statewide-special-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/presidential-general-election-november-4-2008/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2008-general/ssov/10-ballot-measures-statewide-summary.xls
# 20081104_measures_presidential-general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/statewide-direct-primary-election-june-3-2008/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2008-statewide-direct-primary/ssov/detail_ballot_measures_x_tab_09102008_v2.xls
# 20080603_measures_statewide-direct-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/presidential-primary-election-february-5-2008/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2008-primary/ssov/ballot_measures_all.xls
# 20080205_measures_presidential-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-7-2006/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2006-general/ssov/props_sum.xls
# 20061107_measures_general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/gubernatorial-primary-election-june-6-2006/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2006-primary/ssov/props_summary.xls
# 20060606_measures_gubernatorial-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/special-statewide-election-november-8-2005/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2005-special/ssov/ssov_summary_pg_1.xls
# 20051108_measures_special-statewide-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/presidential-general-election-november-2-2004/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2004-general/ssov/formatted_ballot_measures_detail.xls
# 20041102_measures_presidential-general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/presidential-primary-election-march-2-2004/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2004-primary/ssov/ballot_measures_statewide_summary.xls
# 20040302_measures_presidential-primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/statewide-special-election-october-7-2003/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2003-special/ssov/prop_sum.xls
# 20031007_measures_statewide-special-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-5-2002/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2002-general/ssov/prop-sum.xls
# 20021105_measures_general-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/primary-election-march-5-2002/statement-vote/
# http://elections.cdn.sos.ca.gov/sov/2002-primary/ssov/prop-sum.xls
# 20020305_measures_primary-election.xls
#
# http://www.sos.ca.gov/elections/prior-elections/statewide-election-results/general-election-november-7-2000/statement-vote/
# Couldn't find Ballot Measures xls file; exiting

# %%
# First, connect to the page listing all the voter registration records
sess = Session()
url = 'http://www.sos.ca.gov/elections/voter-registration/voter-registration-statistics/'
response = sess.get(url=url)

# grab the html data
html_soup_index = BeautifulSoup(response.text, 'html.parser')
url_base = 'http://www.sos.ca.gov'

# loop over tags containing links to voter registration records
registration_records = html_soup_index.find_all('a',title=re.compile('Report of Registration'))
for tag in registration_records:
    print('\n'+tag['title'])
    date_str = datetime.strptime(re.split('-',tag['title'])[-1],' %B %d, %Y').strftime('%Y%m%d')
    url = tag['href']
    if url[:4] != 'http':
        url = url_base+url
    print(url)
    filename = date_str+'_voter-registration'
    # navigate to page, grab html
    response = sess.get(url=url)
    html_soup = BeautifulSoup(response.text, 'html.parser')
    should_break_inner=False
    for li in html_soup.find_all('li'):
        if should_break_inner: break
        for strong in li.find_all('strong'):  
            match = re.search('[Rr]egistration by [Cc]ounty',strong.text)
            if match and li.find('a',href=re.compile('\.xls')) is not None:
                remote_filename = li.find('a',href=re.compile('\.xls'))['href']
                filename += '.'+re.split('\.',remote_filename)[-1]
                print(remote_filename)
                print(filename)
                wget.download(remote_filename,local_path+filename)
                should_break_inner = True
                break
# Out:
# Report of Registration - January 2, 2018
# http://www.sos.ca.gov/elections/report-registration/report-registration-january-2-2018/
# http://elections.cdn.sos.ca.gov/ror/154day-stwddirprim-2018/county.xls
# 20180102_voter-registration.xls
#
# Report of Registration - February 10, 2017
# http://www.sos.ca.gov/elections/report-registration/ror-odd-year-2017/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/ror-odd-year-2017/county.xlsx
# 20170210_voter-registration.xlsx
#
# Report of Registration - October 24, 2016
# http://www.sos.ca.gov/elections/report-registration/15day-general-2016/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-gen-16/county.xls
# 20161024_voter-registration.xls
#
# Report of Registration - September 9, 2016
# http://www.sos.ca.gov/elections/report-registration/60day-general-2016/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day

# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-prim-10/county.xls
# 20100524_voter-registration.xls
#
# Report of Registration - April 9, 2010
# http://www.sos.ca.gov/elections/report-registration/60day-prim-10/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-prim-10/county.xls
# 20100409_voter-registration.xls
#
# Report of Registration - January 5, 2010
# http://www.sos.ca.gov/elections/report-registration/154day-prim-10/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-prim-10/county.xls
# 20100105_voter-registration.xls
#
# Report of Registration - May 4, 2009
# http://www.sos.ca.gov/elections/report-registration/report-registration-may-4-2009/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-stwdsp-09/county.xls
# 20090504_voter-registration.xls
#
# Report of Registration - March 20, 2009
# http://www.sos.ca.gov/elections/report-registration/ror-032009/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-stwdsp-09/county.xls
# 20090320_voter-registration.xls
#
# Report of Registration - February 10, 2009
# http://www.sos.ca.gov/elections/report-registration/ror-021009/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/ror-odd-year-09/county.xls
# 20090210_voter-registration.xls
#
# Report of Registration - October 20, 2008
# http://www.sos.ca.gov/elections/report-registration/ror-102008/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-presgen-08/county.xls
# 20081020_voter-registration.xls
#
# Report of Registration - September 5, 2008
# http://www.sos.ca.gov/elections/report-registration/ror-09052008/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-presgen-08/county.xls
# 20080905_voter-registration.xls
#
# Report of Registration - May 19, 2008
# http://www.sos.ca.gov/elections/report-registration/ror-05192008/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-stwddirprim-08/county.xls
# 20080519_voter-registration.xls
#
# Report of Registration - April 4, 2008
# http://www.sos.ca.gov/elections/report-registration/ror-040408/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-stwddirprim-08/county.xls
# 20080404_voter-registration.xls
#
# Report of Registration - January 1, 2008
# http://www.sos.ca.gov/elections/report-registration/ror-01012008/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-stwddirprim-08/county.xls
# 20080101_voter-registration.xls
#
# Report of Registration - January 22, 2008
# http://www.sos.ca.gov/elections/report-registration/ror-012208/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-presprim-08/county.xls
# 20080122_voter-registration.xls
#
# Report of Registration - December 7, 2007
# http://www.sos.ca.gov/elections/report-registration/report-registration-december-7-2007/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-presprim-08/county.xls
# 20071207_voter-registration.xls
#
# Report of Registration - September 4, 2007
# http://www.sos.ca.gov/elections/report-registration/ror-09042007/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-presprim-08/county.xls
# 20070904_voter-registration.xls
#
# Report of Registration - February 10, 2007
# http://www.sos.ca.gov/elections/report-registration/report-registration-february-10-2007/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/ror-odd-year-07/county.xls
# 20070210_voter-registration.xls
#
# Report of Registration - October 23, 2006
# http://www.sos.ca.gov/elections/report-registration/ror-102306/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-prim-06/county.xls
# 20061023_voter-registration.xls
#
# Report of Registration - September 8, 2006
# http://www.sos.ca.gov/elections/report-registration/ror-090806/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-gen-06/county.xls
# 20060908_voter-registration.xls
#
# Report of Registration - May 22, 2006
# http://www.sos.ca.gov/elections/report-registration/ror-05222006/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-prim-06/county.xls
# 20060522_voter-registration.xls
#
# Report of Registration - April 7, 2006
# http://www.sos.ca.gov/elections/report-registration/ror-040706/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-prim-06/county.xls
# 20060407_voter-registration.xls
#
# Report of Registration - January 3, 2006
# http://www.sos.ca.gov/elections/report-registration/ror-010306/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-prim-06/county.xls
# 20060103_voter-registration.xls
#
# Report of Registration - October 24, 2005
# http://www.sos.ca.gov/elections/report-registration/ror-10242005/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-spstwd-05/county.xls
# 20051024_voter-registration.xls
#
# Report of Registration - September 9, 2005
# http://www.sos.ca.gov/elections/report-registration/ror-090905/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-spstwd-05/county.xls
# 20050909_voter-registration.xls
#
# Report of Registration - February 10, 2005
# http://www.sos.ca.gov/elections/report-registration/report-registration-february-10-2005/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/ror-odd-year-05/county.xls
# 20050210_voter-registration.xls
#
# Report of Registration - October 18, 2004
# http://www.sos.ca.gov/elections/report-registration/report-registration-october-18-2004/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-presgen-04/county.xls
# 20041018_voter-registration.xls
#
# Report of Registration - September 3, 2004
# http://www.sos.ca.gov/elections/report-registration/ror-090304/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-presgen-04/county.xls
# 20040903_voter-registration.xls
#
# Report of Registration - February 17, 2004
# http://www.sos.ca.gov/elections/report-registration/ror-021704/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-presprim-04/county.xls
# 20040217_voter-registration.xls
#
# Report of Registration - January 2, 2004
# http://www.sos.ca.gov/elections/report-registration/report-registration-january-2-2004/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-presprim-04/county.xls
# 20040102_voter-registration.xls
#
# Report of Registration - September 30, 2003
# http://www.sos.ca.gov/elections/report-registration/ror-09302003/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-presprim-04/county.xls
# 20030930_voter-registration.xls
#
# Report of Registration - September 22, 2003
# http://www.sos.ca.gov/elections/report-registration/ror-092203/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-stwdsp-03/county.xls
# 20030922_voter-registration.xls
#
# Report of Registration - August 8, 2003
# http://www.sos.ca.gov/elections/report-registration/ror-080803/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-stwdsp-03/county.xls
# 20030808_voter-registration.xls
#
# Report of Registration - February 10, 2003
# http://www.sos.ca.gov/elections/report-registration/ror-021003/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/ror-odd-year-03/county.xls
# 20030210_voter-registration.xls
#
# Report of Registration - October 21, 2002
# http://www.sos.ca.gov/elections/report-registration/ror-10212002/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-gen-02/county.xls
# 20021021_voter-registration.xls
#
# Report of Registration - October 7, 2002
# http://www.sos.ca.gov/elections/report-registration/report-registration-october-7-2002/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/29day-gen-02/county.xls
# 20021007_voter-registration.xls
#
# Report of Registration - February 19, 2002
# http://www.sos.ca.gov/elections/report-registration/ror-02192002/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-prim-02/county.xls
# 20020219_voter-registration.xls
#
# Report of Registration - February 19, 2002
# http://www.sos.ca.gov/elections/report-registration/ror-02192002/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/15day-prim-02/county.xls
# 20020219_voter-registration.xls
#
# Report of Registration - February 4, 2002
# http://www.sos.ca.gov/elections/report-registration/ror-02042002/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/29day-prim-02/county.xls
# 20020204_voter-registration.xls
#
# Report of Registration - January 4, 2002
# http://www.sos.ca.gov/elections/report-registration/ror-010402/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/60day-prim-02/county.xls
# 20020104_voter-registration.xls
#
# Report of Registration - October 2, 2001
# http://www.sos.ca.gov/elections/report-registration/ror-100201/
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-prim-02/county.xls
# 20011002_voter-registration.xls
#
# Report of Registration - February 10, 2001
# http://www.sos.ca.gov/elections/report-registration/ror-021001/
#
# Report of Registration - October 10, 2000
# http://www.sos.ca.gov/elections/report-registration/ror-10102000/
#
# Report of Registration - September 8, 2000
# http://www.sos.ca.gov/elections/report-registration/ror-090800/
#
# Report of Registration - February 7, 2000
# http://www.sos.ca.gov/elections/report-registration/ror-02072000/
#
# Report of Registration - January 7, 2000
# http://www.sos.ca.gov/elections/report-registration/ror-010700/
#
# Report of Registration - October 5, 1999
# http://www.sos.ca.gov/elections/report-registration/ror-10051999/
#
# Report of Registration - February 10, 1999
# http://www.sos.ca.gov/elections/report-registration/ror-02101999/

# %%
should_break=False
for li in html_soup.find_all('li'):
    if should_break: break
    for strong in li.find_all('strong'):  
        match = re.search('[Rr]egistration by [Cc]ounty',strong.text)
        if match:
            print(strong.find('a',href=re.compile('\.xls'))['href'])
            should_break = True
            break
# Out:
# http://elections.cdn.sos.ca.gov/ror/ror-pages/154day-presprim-04/county.xls
